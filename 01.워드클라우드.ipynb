# %%
# !pip install wordcloud
# Out:
# 'base'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 다음 명령어를 실행하여 Python 환경에 'ipykernel'을(를) 설치합니다.
#
#  명령: 'conda install -n base ipykernel --update-deps --force-reinstall'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np
# Out:
# 'base'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 다음 명령어를 실행하여 Python 환경에 'ipykernel'을(를) 설치합니다.
#
#  명령: 'conda install -n base ipykernel --update-deps --force-reinstall'

# %%
with open('키워드최종.txt', 'r', encoding='utf-8') as f:
    text = f.read()

okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1]

c = Counter(words)

# %%
wc = WordCloud(font_path='malgun', width=900, height=900, scale=2.0, max_font_size=250,background_color='white')
gen = wc.generate_from_frequencies(c)
plt.figure(figsize = (7, 7)) 
plt.imshow(gen)

# %%
# Out:
# Requirement already satisfied: pip in c:\users\user\anaconda3\lib\site-packages (22.2.2)
# WARNING: Requirement 'JPype1-0.5.7-cp27-none-win_amd64.whl' looks like a filename, but the file does not exist
# ERROR: JPype1-0.5.7-cp27-none-win_amd64.whl is not a supported wheel on this platform.

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\user\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (4.8.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (1.4.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (1.21.5)

# %%
import csv
from collections import Counter
import pandas as pd

# %%
# %pwd
# Out:
# 'C:\\workspace\\크롤러'

# %%
f = open("기사.txt", "r",  encoding="UTF-8")

lines = f.read()

# %%
from konlpy.tag import Twitter

nlpy = Twitter()

nouns = nlpy.nouns(lines)

print(nouns)
# Out:
# ['전자', '탄소', '배출량', '줄', '수량', '배출', '량', '제로', '수준', '탄소', '중립', '달성', '선언', '국내외', '사업', '사용', '전력', '모두', '재생에너지', '전환', '내용', '동참', '전자', '경영', '패러다임', '친환경', '전환', '며', '이', '내용', '반도', '건설', '정렬', '공부', '대표', '가운데', '힘펠', '김철환', '부사', '왼쪽', '대한', '박대', '대표', '지난', '서울', '강남구', '본사', '급', '가압', '설비', '구축', '위', '업무', '협약', '체결', '기념', '촬영', '파이낸셜뉴스', '반도', '건설', '지난', '서울시', '강남구', '테헤란로', '길', '위치', '본사', '반도', '건설', '정렬', '공부', '대표', '힘펠', '김철환', '부사', '대한', '박대', '헤럴드경제', '김상훈', '기자', '한국', '공인', '회계', '사회', '제', '인증', '포럼', '개최', '이번', '포럼', '지난', '한국', '공인', '회계', '사회', '제정', '배포', '지속가능성', '보고서', '등', '대한', '인증', '업무', '기준', '적용', '가이던스', '를', '주제', '진행', '황', '식', '한국', '공인', '회계', '사회', '감사', '기준', '팀', '심', '재경', '삼일', '회계법인', '이사', '황정', '환', '삼정', '회계법인', '파트너', '가이던스', '조선', '호텔', '앤', '리조트', '의미', '환경', '사회', '지배구조', '선포', '경영', '박차', '조선', '호텔', '올해', '초', '추진', '위원회', '를', '발족', '바', '경영', '전략', '내', '달성', '위', '중점', '과제', '수립', '먼저', '폐기물', '배출', '량', '절감', '위', '웨', '이스트', '마이너스', '활동', '전', '사업', '파이낸셜뉴스', '조선', '호텔', '앤', '리조트', '고객', '경영', '실천', '본격', '조선', '호텔', '앤', '리조트', '고객', '임', '직원', '협력', '지역', '사회', '모두', '지속', '여행', '지향', '수', '의미', '선포', '통해', '지속', '호텔', '의', '변화', '더욱', '박차', '조선', '호텔', '올해', '한전', '은', '지난', '나주', '본사', '경영', '실행', '강화', '위', '추진단', '전략', '보고', '회', '를', '개최', '한전', '이', '신설', '추진단', '은', '김장현', '사장', '단장', '환경', '사회', '지배구조', '대외협력', '등', '개', '실행', '조직', '구성', '각', '조직', '해당', '분야', '관련', '전략', '과제', '이행', '발굴', '에너지', '계', '다양', '경영', '확대', '가운데', '싱', '친환경', '위장', '문제', '제기', '성과', '중심', '정책', '의견', '제시', '산업', '연구원', '원장', '주현', '이', '발표', '활성화', '위', '산업', '정책', '과제', '보고서', '일부', '산업', '등급', '기업', '수익률', '더', '현상', '관찰', '등급', '상승', '국내', '산', '한국전력', '정보통', '기술', '부문', '자회사', '한전', '은', '나주시', '본사', '환경', '사회', '공헌', '지배구조', '추진단', '전략', '보고', '회', '를', '개최', '신설', '추진단', '은', '김장현', '한전', '사장', '단장', '환경', '사회', '지배구조', '대외협력', '등', '개', '실행', '조직', '구성', '각', '조직', '해당', '분야', '관련', '전략', '과제', '이행', '발굴', '에너지', '연', '파이낸셜뉴스', '신한은행', '경영', '확대', '안정', '외화', '자금', '조달', '마리', '토끼', '잡기', '위해', '글로벌', '금융기관', '로부터', '활동', '계', '대출', '실행', '신한은행', '지속', '능연', '차입', '은', '대출', '금리', '설정', '방식', '활동', '계', '구조', '자금', '조달', '시', '설정', '파이낸셜뉴스', '유한킴벌리', '지속가능성', '보고서', '발간', '유한킴벌리', '경제', '사회', '환경', '측면', '가치', '창', '출하', '이', '과정', '부하', '과제', '무엇', '이해관계자', '기대', '부응', '위해', '노력', '등', '공개', '올해', '보고서', '사', '청년', '미래', '주최', '제', '청년', '날', '축제', '서울', '올림픽', '공원', '평화', '광장', '개최', '이번', '청년', '날', '행사', '탄소', '중립', '축제', '진행', '국회사무처', '소관', '사단법인', '청년', '미래', '법정기념일', '지정', '위해', '준비', '청년', '날', '법정기념일', '지정', '이번', '청년', '날', '축제', '법정기념일', '지정', '서울', '성동구', '전국', '지방자치단체', '중', '처음', '독자', '환경', '사회', '거버넌스', '지표', '개발', '성동구', '개념', '영역', '활용', '위해', '성동', '지표', '를', '개발', '기업', '가능', '발전', '관', '사회', '책임', '짐', '대두', '기업', '성과', '지표', '최근', '산업', '뿐', '지자체', '등', '영역', '롯데렌탈', '업계', '최초', '기후변화', '관련', '재무', '정보공개', '전담', '협의', '체', '선언', '이행', '지난', '한국', '얼라이언스', '발족', '참여', '데', '이번', '선언', '환경', '경영', '의지', '주요', '개국', '재무', '장관', '및', '중앙은행', '총재', '협의', '체인', '금융', '안정', '위원회', '설립', '이니셔티브', '주요', '바이오', '중유', '사업', '매각', '후', '신재생에너지', '사업', '더욱', '집중', '그린', '파워', '파이낸셜뉴스', '그린', '파워', '경영', '중심', '사업', '구조', '개편', '주목', '그린', '파워', '미래', '경쟁력', '핵심', '사업', '중', '하나', '신재생에너지', '사업', '부문', '개', '프로젝트', '진행', '중이', '라며', '경영', '본격', '롯데', '렌탈', '제공', '파이낸셜뉴스', '롯데렌탈', '지난', '한국', '얼라이언스', '발족', '참여', '업계', '최초', '선언', '이행', '기후변화', '대한', '재무', '정보', '공개', '권고', '안', '수립', '기후변화', '시나리오', '분석', '기반', '잠재', '재정', '리스크', '기회', '가늠', '것', '권고', '안', '주요', '골자', '김현수', '신한은행', '경영', '확대', '안정', '외화', '자금', '조달', '위해', '국내', '최초', '지속', '능연', '차입', '형태', '외화', '클럽', '론', '미화', '차입', '지속', '능연', '차입', '은', '대출', '금리', '설정', '방식', '기업', '지속', '가능', '활동', '계', '구조', '자금', '조달', '시', '설정', '목표', '달성', '금리', '등', '경제', '이익', '한국', '친환경', '기술', '한국', '기업인', '증원', '친환경', '경영', '인프라', '구축', '위', '양해각서', '를', '체결', '한국', '기업인', '증원', '기업', '특성', '시스템', ' ...

# %%
from collections import Counter

# %%
def get_tags(text, ntags=20):
    spliter = Twitter()
    # konlpy의 Twitter객체
    nouns = spliter.nouns(text)
    # nouns 함수를 통해서 text에서 명사만 분리/추출
    count = Counter(nouns)
    # Counter객체를 생성하고 참조변수 nouns할당
    return_list = []  # 명사 빈도수 저장할 변수
    for n, c in count.most_common(ntags):
        temp = {'tag': n, 'count': c}
        return_list.append(temp)
    # most_common 메소드는 정수를 입력받아 객체 안의 명사중 빈도수
    # 큰 명사부터 순서대로 입력받은 정수 갯수만큼 저장되어있는 객체 반환
    # 명사와 사용된 갯수를 return_list에 저장합니다.
    return return_list

# %%
def main():
    text_file_name = "기사.txt"
    # 분석할 파일
    noun_count = 20
    # 최대 많은 빈도수 부터 20개 명사 추출
    output_file_name = "count.txt"
    # count.txt 에 저장
    open_text_file = open(text_file_name, 'r',-1,"utf-8")
    # 분석할 파일을 open 
    text = open_text_file.read() #파일을 읽습니다.
    tags = get_tags(text, noun_count) # get_tags 함수 실행
    open_text_file.close()   #파일 close
    open_output_file = open(output_file_name, 'w',-1,"utf-8")
    # 결과로 쓰일 count.txt 열기
    for tag in tags:
        noun = tag['tag']
        count = tag['count']
        open_output_file.write('{} {}\n'.format(noun, count))
    # 결과 저장
    open_output_file.close() 
 
if __name__ == '__main__':
    main()
